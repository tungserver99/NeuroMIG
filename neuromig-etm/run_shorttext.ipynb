# %%
# !python main.py --wandb_prj neuromax_etm_SearchSnippets_50K --model NeuroMax --dataset SearchSnippets --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 0 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 0
# Out:
# Folder created: results/2025-01-01_00-39-19
# Namespace(dataset='SearchSnippets', model='NeuroMax', num_topics=50, num_groups=20, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=0.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=0.0, beta_temp=0.2, wandb_prj='neuromax_etm_SearchSnippets_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main_tc.py --wandb_prj neuromax_etm_SearchSnippets_50K --model NeuroMax --dataset SearchSnippets --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 30
# Out:
# Folder created: results/2024-12-20_12-14-50
# Namespace(dataset='SearchSnippets', model='NeuroMax', num_topics=50, num_groups=20, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=30.0, beta_temp=0.2, wandb_prj='neuromax_etm_SearchSnippets_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main_tc.py --wandb_prj neuromax_etm_SearchSnippets_50K --model NeuroMax --dataset SearchSnippets --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 50
# Out:
# Folder created: results/2024-12-20_12-32-56
# Namespace(dataset='SearchSnippets', model='NeuroMax', num_topics=100, num_groups=20, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=50.0, beta_temp=0.2, wandb_prj='neuromax_etm_SearchSnippets_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...
