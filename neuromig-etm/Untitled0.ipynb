# %%
# %cd /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm
# Out:
# /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm

# %%
# !pip install -r requirements.txt

# %%
# !pip install python-Levenshtein torch-kmeans

# %%
# !python main.py --wandb_prj NeuroMig_20NG_50K --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 30 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# Out:
# Folder created: results/2025-01-02_00-16-33
# Namespace(dataset='20NG', plm_model='all-mpnet-base-v2', model='NeuroMig', num_topics=50, num_groups=30, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=130.0, beta_temp=0.2, wandb_prj='NeuroMig_20NG_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main.py --wandb_prj NeuroMig_AGNews_50K --model NeuroMig --dataset AGNews --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 0 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 0
# Out:
# Folder created: results/2024-12-16_20-34-46
# Namespace(dataset='AGNews', model='NeuroMig', num_topics=50, num_groups=20, dropout=0.0, use_pretrainWE=True, weight_ECR=40.0, weight_GR=0.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=0.0, beta_temp=0.2, wandb_prj='NeuroMig_AGNews_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main.py --wandb_prj NeuroMig_Yahoo_100K --model NeuroMig --dataset YahooAnswers --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# Out:
# Folder created: results/2024-12-16_04-04-38
# Namespace(dataset='YahooAnswers', model='NeuroMig', num_topics=100, num_groups=20, dropout=0.0, use_pretrainWE=True, weight_ECR=40.0, weight_GR=1.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=150.0, beta_temp=0.2, wandb_prj='NeuroMig_Yahoo_100K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm/wandb/run-20241216_040440-mt6mycp1
# ...

# %%
# !python main.py --wandb_prj NeuroMig_20NG_50K --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# !python main.py --wandb_prj NeuroMig_20NG_50K --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# !python main.py --wandb_prj NeuroMig_AGNews_50K --model NeuroMig --dataset AGNews --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 80
# !python main.py --wandb_prj NeuroMig_AGNews_50K --model NeuroMig --dataset AGNews --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.1 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 1.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_IMDB_50K --model NeuroMig --dataset IMDB --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# !python main.py --wandb_prj NeuroMig_Yahoo_50K --model NeuroMig --dataset YahooAnswers --num_topics 50 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# !python main.py --wandb_prj NeuroMig_20NG_100K --model NeuroMig --dataset 20NG --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.1 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_IMDB_100K --model NeuroMig --dataset IMDB --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130
# !python main.py --wandb_prj NeuroMig_Yahoo_100K --model NeuroMig --dataset YahooAnswers --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --train_WE True --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# Out:
# Folder created: results/2024-12-16_07-39-46
# Namespace(dataset='AGNews', model='NeuroMig', num_topics=50, num_groups=20, dropout=0.1, use_pretrainWE=True, train_WE='True', weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=1.0, weight_InfoNCE=150.0, beta_temp=0.2, wandb_prj='NeuroMig_AGNews_50K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm/wandb/run-20241216_073947-l8oezsn8
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 50 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 30 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 40 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 60 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 10 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# !python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 70 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
#!python main.py --wandb_prj NeuroMig_AGNews_100K --model NeuroMig --dataset AGNews --num_topics 100 --beta_temp 0.2 --num_groups 80 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5 --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150
# Out:
# Folder created: results/2024-12-16_04-54-33
# Namespace(dataset='AGNews', model='NeuroMig', num_topics=100, num_groups=70, dropout=0.0, use_pretrainWE=True, weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=150.0, beta_temp=0.2, wandb_prj='NeuroMig_AGNews_100K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm/wandb/run-20241216_045434-sy0dgsem
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hardy-mountain-36
# ...

# %%
# !python main.py --wandb_prj NeuroMig_20NG_100K --model NeuroMig --dataset 20NG --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1.0  --alpha_ECR 20.0 --alpha_GR 1.0 --weight_InfoNCE 150.0 --seed 0
# Out:
# Folder created: results/2024-12-18_15-21-21
# Namespace(dataset='20NG', model='NeuroMig', num_topics=100, num_groups=20, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=1.0, alpha_ECR=20.0, alpha_GR=1.0, weight_InfoNCE=150.0, beta_temp=0.2, wandb_prj='NeuroMig_20NG_100K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main.py --wandb_prj NeuroMig_20NG_100K --model NeuroMig --dataset 20NG --num_topics 100 --beta_temp 0.2 --num_groups 20 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 1.0  --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 150.0 --seed 0
# Out:
# Folder created: results/2024-12-18_15-08-54
# Namespace(dataset='20NG', model='NeuroMig', num_topics=100, num_groups=20, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=1.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=150.0, beta_temp=0.2, wandb_prj='NeuroMig_20NG_100K', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=0, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kc/.netrc
# wandb: Tracking run with wandb version 0.18.1
# ...

# %%
# !python main.py --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 30 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5.0  --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130.0 --seed 3
# !python main.py --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 30 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5.0  --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130.0 --seed 1
# !python main.py --model NeuroMig --dataset 20NG --num_topics 50 --beta_temp 0.2 --num_groups 30 --epochs 500 --device cuda --lr 0.002 --lr_scheduler StepLR --dropout 0.2 --batch_size 200 --lr_step_size 125 --use_pretrainWE --weight_ECR 40 --weight_GR 5.0  --alpha_ECR 20.0 --alpha_GR 5.0 --weight_InfoNCE 130.0 --seed 2
# Out:
# Folder created: results/2024-12-12_10-12-11
# Namespace(dataset='20NG', model='NeuroMig', num_topics=50, num_groups=30, dropout=0.2, use_pretrainWE=True, weight_ECR=40.0, weight_GR=5.0, alpha_ECR=20.0, alpha_GR=5.0, weight_InfoNCE=130.0, beta_temp=0.2, wandb_prj='topmost', epochs=500, batch_size=200, lr=0.002, device='cuda', seed=3, lr_scheduler='StepLR', lr_step_size=125, tune_SVM=False)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tungserver99 (tunjob). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /content/drive/MyDrive/PHD/neural topic model/NeuroMig/NeuroMig-extend/code/NeuroMig-etm/wandb/run-20241212_101212-gavw9tz3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fluent-moon-43
# ...
